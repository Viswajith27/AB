# %%
import pandas as pd


excel_file_path = r'D:\Dataset.xlsx'

# Define a dictionary to store sheet names and corresponding header rows
headers_dict = {
    'Social Listening_Data': 5,  
    'Google Search_Data': 7,    
    'E-Commerce Reviews_Data': 5,  
    'Brand Tracking_Data': 11   
}

# Load all sheets into a dictionary of DataFrames with different headers
all_sheets = {}
for sheet_name, header_row in headers_dict.items():
    sheet_df = pd.read_excel(excel_file_path, sheet_name=sheet_name, skiprows=header_row)
    all_sheets[sheet_name] = sheet_df

# Access each sheet's DataFrame from the all_sheets dictionary
social_listening_df = all_sheets['Social Listening_Data']
google_search_df = all_sheets['Google Search_Data']
ecommerce_reviews_df = all_sheets['E-Commerce Reviews_Data']
brand_tracking_df = all_sheets['Brand Tracking_Data']

# %%
social_listening_df
# Out:
#      Sl.No    Query Id            Query Name                     Date  \
# 0        1  2000571055  Leffe_UK_DoNotDelete  2021-10-01 20:40:13.000
# 1        2  2000571055  Leffe_UK_DoNotDelete  2021-03-15 21:59:55.000
# 2        3  2000571055  Leffe_UK_DoNotDelete  2021-11-20 21:09:54.000
# 3        4  2000571055  Leffe_UK_DoNotDelete  2022-03-12 18:44:09.000
# 4        5  2000571055  Leffe_UK_DoNotDelete  2022-01-20 18:11:03.000
# ..     ...         ...                   ...                      ...
# 145    146  2000571055  Leffe_UK_DoNotDelete  2022-07-01 19:24:57.000
# 146    147  2000571055  Leffe_UK_DoNotDelete  2023-04-07 16:56:20.000
# 147    148  2000571055  Leffe_UK_DoNotDelete  2022-08-24 19:38:23.000
# 148    149  2000571055  Leffe_UK_DoNotDelete  2021-02-18 18:01:37.000
# 149    150  2000571055  Leffe_UK_DoNotDelete  2022-03-23 20:11:46.000
#
#                                                  Title  \
# 0              @R1100GSBlueNose I'm on the Leffe. Yum!
# ...

# %%
google_search_df
# Out:
#      Unnamed: 0 Top Related Queries/Search Interest Score  Unnamed: 3    Week  \
# 0           NaN                      leffe            100         NaN  Jan'21
# 1           NaN                 leffe beer             43         NaN  Jan'21
# 2           NaN               leffe blonde             22         NaN  Jan'21
# 3           NaN                leffe glass              7         NaN  Jan'21
# 4           NaN          leffe blonde beer              7         NaN  Jan'21
# ..          ...                        ...            ...         ...     ...
# 296         NaN                        NaN            NaN         NaN     NaN
# 297         NaN                        NaN            NaN         NaN     NaN
# 298         NaN                        NaN            NaN         NaN     NaN
# 299         NaN                        NaN            NaN         NaN     NaN
# 300         NaN                        NaN            NaN         NaN     NaN
#
# ...

# %%
ecommerce_reviews_df
# Out:
#     Sl.No Flavour Name                                             Review  \
# 0       1       Blonde  I really like this beer but I want the rest of...
# 1       2         Ruby  rubbish, when I ordered it was two days premiu...
# 2       3         Ruby  This is a Berry flavoured beer and tastes real...
# 3       4         Ruby  Sorry to say didn’t like this at all, but wort...
# 4       5         Ruby  Buyer beware.\nAfter reading reviews about how...
# ..    ...          ...                                                ...
# 68     69       Blonde  This is, in my opinion, the best lager you can...
# 69     70       Blonde  I would recommend this to any fans of quality ...
# 70     71       Blonde  I would definitely recommend. Great Beer.\nGoo...
# 71     72       Blonde  "The Leffe Blonde Belgian Abbey Beer is a must...
# 72     73       Blonde     Got this discounted so was a no brainer to buy
#
#                                                  Link
# ...

# %%
brand_tracking_df
# Out:
#                                InMarket Facilitators   2020 (NET)  2021 (NET)  \
# 0                              It was at a good price       0.193       0.153
# 1       It was served in special glassware or bottles       0.143       0.143
# 2    It had the amount of alcohol (ABV) that I wanted       0.104       0.138
# 3   It came in the format I wanted (e.g. bottle, c...       0.115       0.199
# 4                                 It was easy to find       0.086       0.102
# 5               It was on sale, special, or promotion       0.093       0.083
# 6                               I liked the packaging       0.100       0.118
# 7                  It was available on tap or draught       0.130       0.093
# 8                            It was recommended to me       0.193       0.144
# 9   It came in flavours and types I like (e.g. Lig...       0.117       0.144
# 10  It came in the pack size I wanted and others d...       0.082       0.133
# ...

# %%
google_search_df.isnull().sum()
# Out:
# Unnamed: 0                    301
# Top Related Queries/Search    285
# Interest Score                285
# Unnamed: 3                    301
# Week                          162
# Interest Score.1              162
# Unnamed: 6                    301
# Region                        297
# Interest Score.2              297
# Unnamed: 9                    301
# Unnamed: 10                   301
# Unnamed: 11                   301
# Keyword                         0
# Avg. monthly searches           7
# dtype: int64

# %%
google_search_df.describe()
# Out:
#        Unnamed: 0  Unnamed: 3  Interest Score.1  Unnamed: 6  Interest Score.2  \
# count         0.0         0.0        139.000000         0.0          4.000000
# mean          NaN         NaN         55.273381         NaN         81.000000
# std           NaN         NaN         13.056625         NaN         25.442746
# min           NaN         NaN         25.000000         NaN         44.000000
# 25%           NaN         NaN         45.500000         NaN         74.750000
# 50%           NaN         NaN         55.000000         NaN         90.000000
# 75%           NaN         NaN         64.000000         NaN         96.250000
# max           NaN         NaN        100.000000         NaN        100.000000
#
#        Unnamed: 9  Unnamed: 10  Unnamed: 11  Avg. monthly searches
# count         0.0          0.0          0.0             294.000000
# mean          NaN          NaN          NaN             127.210884
# ...

# %%
google_search_df.columns
# Out:
# Index(['Unnamed: 0', 'Top Related Queries/Search', 'Interest Score',
#        'Unnamed: 3', 'Week', 'Interest Score.1', 'Unnamed: 6', 'Region',
#        'Interest Score.2', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Keyword', 'Avg. monthly searches'],
#       dtype='object')

# %%
social_listening_df.columns
# Out:
# Index(['Sl.No', 'Query Id', 'Query Name', 'Date', 'Title',
#        'Social Mention/Comment', 'Url', 'Domain', 'Sentiment', 'Emotion',
#        'Page Type', 'Language', 'Country Code', 'Continent Code', 'Continent',
#        'Country', 'Region Code', 'Region', 'City Code', 'Account Type',
#        'Assignment', 'Author', 'Avatar', 'Category Details', 'Checked', 'City',
#        'Display URLs', 'Expanded URLs', 'Facebook Author ID',
#        'Facebook Comments', 'Facebook Likes', 'Facebook Role',
#        'Facebook Shares', 'Facebook Subtype', 'Full Name', 'Gender',
#        'Hashtags', 'Impact', 'Impressions', 'Instagram Comments',
#        'Instagram Followers', 'Instagram Following', 'Instagram Likes',
#        'Instagram Posts', 'Interest', 'Last Assignment Date', 'Latitude',
#        'Location Name', 'Longitude', 'Media Filter', 'Media URLs',
#        'Mentioned Authors', 'Priority', 'Professions', 'Resource Id',
# ...

# %%
ecommerce_reviews_df.columns
# Out:
# Index(['Sl.No', 'Flavour Name', 'Review', 'Link'], dtype='object')

# %%
brand_tracking_df.columns
# Out:
# Index(['InMarket Facilitators ', '2020 (NET)', '2021 (NET)', '2022 (NET)',
#        'H1'20', 'H1'21', 'H1'22', 'H1'23'],
#       dtype='object')

# %%
# Rename relevant columns
google_search_df = google_search_df.rename(columns={'Top Related Queries/Search': 'Queries', 'Interest Score': 'Interest_Queries', 'Week': 'Week', 'Interest Score.1': 'Interest_Week', 'Region': 'Region', 'Interest Score.2': 'Interest_Region', 'Keyword': 'Keyword', 'Avg. monthly searches': 'AvgMonthlySearches'})


google_search_df = google_search_df[['Queries', 'Interest_Queries', 'Week', 'Interest_Week', 'Region', 'Interest_Region', 'Keyword', 'AvgMonthlySearches']]

# %%
google_search_df
# Out:
#                Queries Interest_Queries    Week  Interest_Week  \
# 0                leffe              100  Jan'21           44.0
# 1           leffe beer               43  Jan'21           57.0
# 2         leffe blonde               22  Jan'21           44.0
# 3          leffe glass                7  Jan'21           42.0
# 4    leffe blonde beer                7  Jan'21           52.0
# ..                 ...              ...     ...            ...
# 296                NaN              NaN     NaN            NaN
# 297                NaN              NaN     NaN            NaN
# 298                NaN              NaN     NaN            NaN
# 299                NaN              NaN     NaN            NaN
# 300                NaN              NaN     NaN            NaN
#
#                Region  Interest_Region                 Keyword  \
# 0    Northern Ireland             44.0                   leffe
# 1             England             85.0              leffe beer
# ...

# %%
social_listening_df.columns
# Out:
# Index(['Sl.No', 'Query Id', 'Query Name', 'Date', 'Title',
#        'Social Mention/Comment', 'Url', 'Domain', 'Sentiment', 'Emotion',
#        'Page Type', 'Language', 'Country Code', 'Continent Code', 'Continent',
#        'Country', 'Region Code', 'Region', 'City Code', 'Account Type',
#        'Assignment', 'Author', 'Avatar', 'Category Details', 'Checked', 'City',
#        'Display URLs', 'Expanded URLs', 'Facebook Author ID',
#        'Facebook Comments', 'Facebook Likes', 'Facebook Role',
#        'Facebook Shares', 'Facebook Subtype', 'Full Name', 'Gender',
#        'Hashtags', 'Impact', 'Impressions', 'Instagram Comments',
#        'Instagram Followers', 'Instagram Following', 'Instagram Likes',
#        'Instagram Posts', 'Interest', 'Last Assignment Date', 'Latitude',
#        'Location Name', 'Longitude', 'Media Filter', 'Media URLs',
#        'Mentioned Authors', 'Priority', 'Professions', 'Resource Id',
# ...

# %%
# Select relevant columns
selected_columns = ['Query Name', 'Query Id', 'Date', 'Sentiment', 'Emotion', 'Country', 'City', 'Interest', 'Twitter Tweets',
                    'Title', 'Social Mention/Comment', 'Url', 'Region', 'Gender', 'Professions', 'Domain', 'Page Type', 'Language',
                    'Facebook Likes', 'Facebook Shares', 'Twitter Retweets', 'Instagram Likes',
                    'Reddit Score', 'Subreddit Subscribers', 'EPL Teams']

social_listening_df = social_listening_df[selected_columns]

# Analyze sentiment distribution
sns.countplot(x='Sentiment', data=social_listening_df)
plt.title('Sentiment Distribution')
plt.show()

# Analyze emotion distribution
sns.countplot(x='Emotion', data=social_listening_df)
plt.title('Emotion Distribution')
plt.show()

# %%
social_metrics = social_listening_df[['Facebook Likes', 'Facebook Shares', 'Twitter Retweets', 'Twitter Tweets','Instagram Likes', 'Reddit Score', 'Subreddit Subscribers']]
metrics_summary = social_metrics.describe()
metrics_summary
# Out:
#        Facebook Likes  Facebook Shares  Twitter Retweets  Twitter Tweets  \
# count           150.0            150.0        150.000000      150.000000
# mean              0.0              0.0          0.113333    26231.433333
# std               0.0              0.0          0.629655    46218.538217
# min               0.0              0.0          0.000000       60.000000
# 25%               0.0              0.0          0.000000     3590.000000
# 50%               0.0              0.0          0.000000    11225.500000
# 75%               0.0              0.0          0.000000    23369.750000
# max               0.0              0.0          6.000000   315083.000000
#
#        Instagram Likes  Reddit Score  Subreddit Subscribers
# count            150.0           0.0                    0.0
# mean               0.0           NaN                    NaN
# std                0.0           NaN                    NaN
# min                0.0           NaN                    NaN
# ...

# %%
metrics_corr = social_metrics.corr()
metrics_corr
# Out:
#                        Facebook Likes  Facebook Shares  Twitter Retweets  \
# Facebook Likes                    NaN              NaN               NaN
# Facebook Shares                   NaN              NaN               NaN
# Twitter Retweets                  NaN              NaN          1.000000
# Twitter Tweets                    NaN              NaN         -0.053577
# Instagram Likes                   NaN              NaN               NaN
# Reddit Score                      NaN              NaN               NaN
# Subreddit Subscribers             NaN              NaN               NaN
#
#                        Twitter Tweets  Instagram Likes  Reddit Score  \
# Facebook Likes                    NaN              NaN           NaN
# Facebook Shares                   NaN              NaN           NaN
# Twitter Retweets            -0.053577              NaN           NaN
# Twitter Tweets               1.000000              NaN           NaN
# ...

# %%
keyword_counts = social_listening_df['Query Name'].value_counts()
keyword_counts
# Out:
# Leffe_UK_DoNotDelete    150
# Name: Query Name, dtype: int64

# %%
page_type_counts = social_listening_df['Page Type'].value_counts()
page_type_counts
# Out:
# twitter    150
# Name: Page Type, dtype: int64

# %%
language_counts = social_listening_df['Language'].value_counts()
language_counts
# Out:
# en           140
# undefined      2
# ca             2
# ro             1
# es             1
# ht             1
# fr             1
# pt             1
# de             1
# Name: Language, dtype: int64

# %%
country_counts = social_listening_df['Country'].value_counts()
country_counts
# Out:
# United Kingdom    150
# Name: Country, dtype: int64

# %%
social_listening_df.columns
# Out:
# Index(['Query Name', 'Query Id', 'Date', 'Sentiment', 'Emotion', 'Country',
#        'City', 'Interest', 'Twitter Tweets', 'Title', 'Social Mention/Comment',
#        'Url', 'Region', 'Gender', 'Professions', 'Domain', 'Page Type',
#        'Language', 'Facebook Likes', 'Facebook Shares', 'Twitter Retweets',
#        'Instagram Likes', 'Reddit Score', 'Subreddit Subscribers',
#        'EPL Teams'],
#       dtype='object')

# %%
city_counts = social_listening_df['City'].value_counts()
city_counts
# Out:
# London                17
# Glasgow                8
# Manchester             6
# Newcastle              6
# Liverpool              5
# Reading                5
# Leeds                  4
# Cardiff                3
# Ipswich                3
# Birmingham             3
# Bournemouth            2
# Edinburgh              2
# Stoke                  2
# Oxford                 2
# Doncaster              2
# Northampton            2
# Bristol                2
# Gloucester             2
# Peterborough           1
# Dundee                 1
# Leicester              1
# Kingston upon Hull     1
# Swansea                1
# Carlisle               1
# Perth                  1
# Southend-on-Sea        1
# Inverness              1
# Broadstairs            1
# Portsmouth             1
# Lincoln                1
# Taunton                1
# Cambridge              1
# Norwich                1
# Name: City, dtype: int64

# %%
gender_counts = social_listening_df['Gender'].value_counts()
gender_counts
# Out:
# male       82
# unknown    50
# female     15
# Name: Gender, dtype: int64

# %%
professions_counts = social_listening_df['Professions'].value_counts()
professions_counts
# Out:
# Scientist & Researcher (Historian)                                 2
# Teacher & Lecturer (Teacher), Artist (Actor)                       2
# Legal (Judge), Executive (Owner), Teacher & Lecturer (Educator)    1
# Teacher & Lecturer (Teacher)                                       1
# Executive (Co-chair)                                               1
# Politician (Mayor), Politician (MP)                                1
# Artist (Creative Director)                                         1
# Artist (Producer)                                                  1
# Software developer & IT (Coder)                                    1
# Artist (Photographer)                                              1
# Politician (Councillor)                                            1
# Journalist (Correspondent)                                         1
# Executive (Co-founder), Executive (CTO)                            1
# Executive (Executive Director)                                     1
# ...

# %%
region_counts = social_listening_df['Region'].value_counts()
region_counts
# Out:
# Greater London                18
# South East England            15
# North West England            14
# East England                  12
# South Western Scotland        10
# Yorkshire and the Humber       9
# South West England             8
# North East England             6
# West Midlands                  6
# Eastern Scotland               5
# East Midlands                  4
# Northern Ireland               3
# West Wales and the Valleys     3
# Highlands and Islands          2
# East Wales                     1
# Name: Region, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob

# %%
ecom_reviews_df = ecommerce_reviews_df[['Flavour Name', 'Review', 'Link']]

# %%
ecom_reviews_df
# Out:
#    Flavour Name                                             Review  \
# 0        Blonde  I really like this beer but I want the rest of...
# 1          Ruby  rubbish, when I ordered it was two days premiu...
# 2          Ruby  This is a Berry flavoured beer and tastes real...
# 3          Ruby  Sorry to say didn’t like this at all, but wort...
# 4          Ruby  Buyer beware.\nAfter reading reviews about how...
# ..          ...                                                ...
# 68       Blonde  This is, in my opinion, the best lager you can...
# 69       Blonde  I would recommend this to any fans of quality ...
# 70       Blonde  I would definitely recommend. Great Beer.\nGoo...
# 71       Blonde  "The Leffe Blonde Belgian Abbey Beer is a must...
# 72       Blonde     Got this discounted so was a no brainer to buy
#
#                                                  Link
# 0   https://www.amazon.co.uk/gp/customer-reviews/R...
# ...

# %%
ecom_reviews_df['Sentiment'] = ecom_reviews_df['Review'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

# %%
flavour_counts = ecom_reviews_df['Flavour Name'].value_counts()

# %%
link_counts = ecom_reviews_df['Link'].value_counts()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=flavour_counts.index, y=flavour_counts.values)
plt.title('Distribution of Reviews Across Flavors')
plt.xlabel('Flavour')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=link_counts.index, y=link_counts.values)
plt.title('Distribution of Reviews Across Links')
plt.xlabel('Product Link')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
print("E-Commerce Reviews DataFrame with Sentiment:")
print(ecom_reviews_df[['Flavour Name', 'Review', 'Sentiment']])
# Out:
# E-Commerce Reviews DataFrame with Sentiment:
#    Flavour Name                                             Review  Sentiment
# 0        Blonde  I really like this beer but I want the rest of...   0.200000
# 1          Ruby  rubbish, when I ordered it was two days premiu...   0.000000
# 2          Ruby  This is a Berry flavoured beer and tastes real...   0.261111
# 3          Ruby  Sorry to say didn’t like this at all, but wort...   0.200000
# 4          Ruby  Buyer beware.\nAfter reading reviews about how...   0.172222
# ..          ...                                                ...        ...
# 68       Blonde  This is, in my opinion, the best lager you can...   0.305556
# 69       Blonde  I would recommend this to any fans of quality ...  -0.093333
# 70       Blonde  I would definitely recommend. Great Beer.\nGoo...   0.239167
# 71       Blonde  "The Leffe Blonde Belgian Abbey Beer is a must...   0.174074
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(ecom_reviews_df['Sentiment'], bins=30, kde=True, color='skyblue')
plt.title('Sentiment Distribution of E-Commerce Reviews')
plt.xlabel('Sentiment Polarity')
plt.ylabel('Frequency')
plt.show()

# %%
brand_tracking_df
# Out:
#                                InMarket Facilitators   2020 (NET)  2021 (NET)  \
# 0                              It was at a good price       0.193       0.153
# 1       It was served in special glassware or bottles       0.143       0.143
# 2    It had the amount of alcohol (ABV) that I wanted       0.104       0.138
# 3   It came in the format I wanted (e.g. bottle, c...       0.115       0.199
# 4                                 It was easy to find       0.086       0.102
# 5               It was on sale, special, or promotion       0.093       0.083
# 6                               I liked the packaging       0.100       0.118
# 7                  It was available on tap or draught       0.130       0.093
# 8                            It was recommended to me       0.193       0.144
# 9   It came in flavours and types I like (e.g. Lig...       0.117       0.144
# 10  It came in the pack size I wanted and others d...       0.082       0.133
# ...

# %%
brand_tracking_df.columns
# Out:
# Index(['InMarket Facilitators ', '2020 (NET)', '2021 (NET)', '2022 (NET)',
#        'H1'20', 'H1'21', 'H1'22', 'H1'23'],
#       dtype='object')

# %%
brand_tracking_df.columns = brand_tracking_df.columns.str.strip()

# %%
brand_tracking_df = brand_tracking_df[['InMarket Facilitators', '2020 (NET)', '2021 (NET)', '2022 (NET)', 'H1\'20', 'H1\'21', 'H1\'22', 'H1\'23']]

# %%
# 2. Visualization - Trends Over Different Years
plt.figure(figsize=(12, 8))
sns.lineplot(data=brand_tracking_df.set_index('InMarket Facilitators').transpose())
plt.title('InMarket Facilitators Trends Over Different Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='InMarket Facilitators', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 8))
brand_tracking_df.set_index('InMarket Facilitators').transpose().plot(kind='bar', stacked=True)
plt.title('InMarket Facilitators Trends Over Different Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(title='InMarket Facilitators', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(brand_tracking_df.set_index('InMarket Facilitators').transpose(), cmap='coolwarm', annot=True, fmt=".1f")
plt.title('InMarket Facilitators Trends Over Different Years')
plt.xlabel('InMarket Facilitators')
plt.ylabel('Year')
plt.show()

# %%
google_search_df
# Out:
#                Queries Interest_Queries    Week  Interest_Week  \
# 0                leffe              100  Jan'21           44.0
# 1           leffe beer               43  Jan'21           57.0
# 2         leffe blonde               22  Jan'21           44.0
# 3          leffe glass                7  Jan'21           42.0
# 4    leffe blonde beer                7  Jan'21           52.0
# ..                 ...              ...     ...            ...
# 296                NaN              NaN     NaN            NaN
# 297                NaN              NaN     NaN            NaN
# 298                NaN              NaN     NaN            NaN
# 299                NaN              NaN     NaN            NaN
# 300                NaN              NaN     NaN            NaN
#
#                Region  Interest_Region                 Keyword  \
# 0    Northern Ireland             44.0                   leffe
# 1             England             85.0              leffe beer
# ...

# %%
# Group 1: Queries and Interest_Queries
group1_cols = ['Queries', 'Interest_Queries']
group1_df = google_search_df[group1_cols]

# Group 2: Week and Interest_Week
group2_cols = ['Week', 'Interest_Week']
group2_df = google_search_df[group2_cols]

# Group 3: Region and Interest_Region
group3_cols = ['Region', 'Interest_Region']
group3_df = google_search_df[group3_cols]

# Group 4: Keyword and AvgMonthlySearches
group4_cols = ['Keyword', 'AvgMonthlySearches']
group4_df = google_search_df[group4_cols]

# Display the first few rows of each group to verify
print("Group 1:")
print(group1_df.head())
print("\nGroup 2:")
print(group2_df.head())
print("\nGroup 3:")
print(group3_df.head())
print("\nGroup 4:")
print(group4_df.head())
# Out:
# Group 1:
#              Queries Interest_Queries
# 0              leffe              100
# 1         leffe beer               43
# 2       leffe blonde               22
# 3        leffe glass                7
# 4  leffe blonde beer                7
#
# Group 2:
#      Week  Interest_Week
# 0  Jan'21           44.0
# 1  Jan'21           57.0
# 2  Jan'21           44.0
# 3  Jan'21           42.0
# 4  Jan'21           52.0
#
# Group 3:
#              Region  Interest_Region
# 0  Northern Ireland             44.0
# 1           England             85.0
# 2             Wales             95.0
# 3          Scotland            100.0
# 4               NaN              NaN
#
# Group 4:
#         Keyword  AvgMonthlySearches
# 0         leffe              5400.0
# 1    leffe beer              8100.0
# 2  leffe blonde              4400.0
# 3    leffe ruby              1000.0
# 4   leffe brune               880.0

# %%
# Convert "<1" to NaN in the Interest_Queries column
group1_df['Interest_Queries'] = pd.to_numeric(group1_df['Interest_Queries'], errors='coerce')

# Display unique queries and their corresponding interest scores
print("Unique Queries and Interest Scores:")
print(group1_df[['Queries', 'Interest_Queries']].drop_duplicates())

# Visualize the distribution of interest scores
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(data=group1_df, x='Interest_Queries', bins=20, kde=True)
plt.title('Distribution of Interest Scores for Queries')
plt.xlabel('Interest Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\91900\AppData\Local\Temp\ipykernel_9824\3823129034.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group1_df['Interest_Queries'] = pd.to_numeric(group1_df['Interest_Queries'], errors='coerce')
# Unique Queries and Interest Scores:
#                     Queries  Interest_Queries
# 0                     leffe             100.0
# 1                leffe beer              43.0
# 2              leffe blonde              22.0
# 3               leffe glass               7.0
# 4         leffe blonde beer               7.0
# 5               blonde beer               7.0
# 6                ruby leffe               4.0
# 7               leffe brune               4.0
# 8          leffe percentage               3.0
# ...

# %%
# Display unique weeks and their corresponding interest scores
print("Unique Weeks and Interest Scores:")
print(group2_df[['Week', 'Interest_Week']].drop_duplicates())

# Visualize the trend of interest scores over weeks with rotated x-axis labels
plt.figure(figsize=(12, 6))
sns.lineplot(x='Week', y='Interest_Week', data=group2_df)
plt.title('Interest Scores Over Weeks')
plt.xlabel('Week')
plt.ylabel('Interest Score')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better visualization
plt.show()
# Out:
# Unique Weeks and Interest Scores:
#        Week  Interest_Week
# 0    Jan'21           44.0
# 1    Jan'21           57.0
# 3    Jan'21           42.0
# 4    Jan'21           52.0
# 5    Feb'21           56.0
# ..      ...            ...
# 134  Jul'23           62.0
# 135  Aug'23           64.0
# 136  Aug'23           68.0
# 137  Aug'23           66.0
# 139     NaN            NaN
#
# [134 rows x 2 columns]

# %%
# Display unique regions and their corresponding interest scores
print("Unique Regions and Interest Scores:")
print(group3_df[['Region', 'Interest_Region']].drop_duplicates())

# Visualize interest scores by region
plt.figure(figsize=(12, 6))
sns.barplot(x='Region', y='Interest_Region', data=group3_df)
plt.title('Interest Scores by Region')
plt.xlabel('Region')
plt.ylabel('Interest Score')
plt.show()
# Out:
# Unique Regions and Interest Scores:
#              Region  Interest_Region
# 0  Northern Ireland             44.0
# 1           England             85.0
# 2             Wales             95.0
# 3          Scotland            100.0
# 4               NaN              NaN

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=group4_df, x='AvgMonthlySearches', order=group4_df['AvgMonthlySearches'].value_counts().index)
plt.title('Distribution of Average Monthly Searches for Keywords')
plt.xlabel('Avg Monthly Searches')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
unique_values = group4_df['AvgMonthlySearches'].unique()
unique_values.sort()
unique_values
# Out:
# array([   0.,   10.,   20.,   30.,   40.,   50.,   70.,   90.,  110.,
#         140.,  170.,  210.,  260.,  480.,  880., 1000., 4400., 5400.,
#        8100.,   nan])

# %%
unique_values = group4_df['Keyword'].unique()
a=unique_values
print(len(a))
# Out:
# 301

# %%
social_listening_df.columns
# Out:
# Index(['Query Name', 'Query Id', 'Date', 'Sentiment', 'Emotion', 'Country',
#        'City', 'Interest', 'Twitter Tweets', 'Title', 'Social Mention/Comment',
#        'Url', 'Region', 'Gender', 'Professions', 'Domain', 'Page Type',
#        'Language', 'Facebook Likes', 'Facebook Shares', 'Twitter Retweets',
#        'Instagram Likes', 'Reddit Score', 'Subreddit Subscribers',
#        'EPL Teams'],
#       dtype='object')

# %%
social_listening_dff = all_sheets['Social Listening_Data']
social_listening_dff.columns
# Out:
# Index(['Sl.No', 'Query Id', 'Query Name', 'Date', 'Title',
#        'Social Mention/Comment', 'Url', 'Domain', 'Sentiment', 'Emotion',
#        'Page Type', 'Language', 'Country Code', 'Continent Code', 'Continent',
#        'Country', 'Region Code', 'Region', 'City Code', 'Account Type',
#        'Assignment', 'Author', 'Avatar', 'Category Details', 'Checked', 'City',
#        'Display URLs', 'Expanded URLs', 'Facebook Author ID',
#        'Facebook Comments', 'Facebook Likes', 'Facebook Role',
#        'Facebook Shares', 'Facebook Subtype', 'Full Name', 'Gender',
#        'Hashtags', 'Impact', 'Impressions', 'Instagram Comments',
#        'Instagram Followers', 'Instagram Following', 'Instagram Likes',
#        'Instagram Posts', 'Interest', 'Last Assignment Date', 'Latitude',
#        'Location Name', 'Longitude', 'Media Filter', 'Media URLs',
#        'Mentioned Authors', 'Priority', 'Professions', 'Resource Id',
# ...
